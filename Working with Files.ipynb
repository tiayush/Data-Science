# %%
file_obj = open('lorem.txt')
file_obj
# Out:
# <_io.TextIOWrapper name='lorem.txt' mode='r' encoding='UTF-8'>

# %%
file_obj = open('lorem.txt', 'w')

# %%
file_obj = open('lorem.txt', 'a')

# %%
file_obj = open('lorem.txt')
file_data = file_obj.read()
file_data
# Out:
# 'Lorem ipsum dolor sit amet, consetetur sadipscing elitr, sed diam nonumy eirmod tempor invidunt ut labore et dolore magna aliquyam erat, sed diam voluptua. At vero eos et accusam et justo duo dolores et ea rebum. Stet clita kasd gubergren, no sea takimata sanctus est Lorem ipsum dolor sit amet. Lorem ipsum dolor sit amet, consetetur sadipscing elitr, sed diam nonumy eirmod tempor invidunt ut labore et dolore magna aliquyam erat, sed diam voluptua. At vero eos et accusam et justo duo dolores et ea rebum. Stet clita kasd gubergren, no sea takimata sanctus est Lorem ipsum dolor sit amet. Lorem ipsum dolor sit amet, consetetur sadipscing elitr, sed diam nonumy eirmod tempor invidunt ut labore et dolore magna aliquyam erat, sed diam voluptua. At vero eos et accusam et justo duo dolores et ea rebum. Stet clita kasd gubergren, no sea takimata sanctus est Lorem ipsum dolor sit amet.   \n\nDuis autem vel eum iriure dolor in hendrerit in vulputate velit esse molestie consequat, vel illum dolo
# ...

# %%
file_obj = open('lorem.txt')
file_data = file_obj.read(10)
print(file_data)
# readline() prints min(length og line, no of characters passed)
# Out:
# Lorem ipsu

# %%
file_obj = open('lorem.txt', 'r')
file_data = file_obj.readline()
# file_data
print(file_data)
print(file_obj.readline())
print(file_obj.readline())
# Out:
# Lorem ipsum dolor sit amet, consetetur sadipscing elitr, sed diam nonumy eirmod tempor invidunt ut labore et dolore magna aliquyam erat, sed diam voluptua. At vero eos et accusam et justo duo dolores et ea rebum. Stet clita kasd gubergren, no sea takimata sanctus est Lorem ipsum dolor sit amet. Lorem ipsum dolor sit amet, consetetur sadipscing elitr, sed diam nonumy eirmod tempor invidunt ut labore et dolore magna aliquyam erat, sed diam voluptua. At vero eos et accusam et justo duo dolores et ea rebum. Stet clita kasd gubergren, no sea takimata sanctus est Lorem ipsum dolor sit amet. Lorem ipsum dolor sit amet, consetetur sadipscing elitr, sed diam nonumy eirmod tempor invidunt ut labore et dolore magna aliquyam erat, sed diam voluptua. At vero eos et accusam et justo duo dolores et ea rebum. Stet clita kasd gubergren, no sea takimata sanctus est Lorem ipsum dolor sit amet.
#
# ...

# %%
# inorder to read multiple lines we make use iof
# readlines() which returns a list of lines
file_obj = open('lorem.txt')
file_data = file_obj.readlines()
print(type(file_data))
print(file_data)
file_obj.close()
# Out:
# <class 'list'>
# ...

# %%
with open('lorem.txt') as file_obj:
    file_data = file_obj.readlines()
print(type(file_data))
# Out:
# <class 'list'>
